# %% [markdown]
# # DSCI 521 - Data Analysis and Interpretation
# #### Term Project Phase 1: Scoping an analytics project

# %% [markdown]
# ## Team Details
#
# 1. Abhinav Mani Tripathi
#
#     Q. What areas/skills/domains does the team member presently identify with?
#
#     A. Analytical Skill – Data Analysis, Data Manipulation, Research and Testing Hypotheses. <br> Mathematics - Creating and Maintaining Algorithms and Statistics. <br> Programming Skill – Python and R.
#
#     Q. Into which areas/skills/domains would the team member like to grow?
#
#     A. Data Analysis and Machine Learning using Python.
#
# 2. Aishwarya Ravi
#
#     Q. What areas/skills/domains does the team member presently identify with?
#
#     A. Data Acquisition and data preprocessing
#
#     Q. Into which areas/skills/domains would the team member like to grow?
#
#     A. Methods to Observe, explore and interpret data for better analysis.
#
# 3. Awanish Tiwari
#
#     Q. What areas/skills/domains does the team member presently identify with?
#
#     A. Having a good command in Banking and Insurance domain. Good at applying logics and following timelines. Earlier worked with DB2(Mainframe Database) so having good SQL command as well. Data Analysis and Testing hypothesis is strongest among other skill set.
#
#     Q. Into which areas/skills/domains would the team member like to grow?
#
#     A.  Looking forward to command over Financial domain and digital skills for application development.
#
# 4. Nupur Roy Chaudhary
#
#     Q. What areas/skills/domains does the team member presently identify with?
#
#     A. Being a software developer and while studying for the Masters in DataScience the areas/skills  which I presently identify with includes : Software Engineering , programming , Data Analytics , Data pre-processing and programming tools.
#
#     Q. Into which areas/skills/domains would the team member like to grow?
#
#     A. The areas which I would like to grow myself and build a firm foundation includes : Data Visualization and Communication, Data Intuition, Data Wrangling, Machine learning and the current subject of Multivariable Calculus and Linear Algebra.

# %% [markdown]
# ## TOPIC : WoRLD of World

# %% [markdown]
# #### ● Discussion of what you would like to your analysis to do, who/what it will support
#
# WoRLD or World Revenue Longitudinal Data is compilation of government tax and non-tax revenuesfrom IMF's Government Financial Statistics. It's strength lies primarily in the breadth of its countries and time. This dataset can be used to encourage the analytical work on revenue, policy and administration, and macro fiscal policy more generally, particularly in relation to developing economies.
#
# We are also including the international trade data to cover more robust analysis of GDP variation of different countries. The growing tradability of services is critical for competitiveness of advanced economies.The rise of services trade is a particular crucial engine of trade, growth and jobs in country thus play a vital role in GDP.
#
# Under this project we are identifying the benefic and malefic indicators which lays strong impact in National GDP. Also we are using the time series prediction of final values as our end result.

# %% [markdown]
# #### ● Exhibition of analyses from dataset(s) explored, including visual analyses, captions, and useful descripitions
#
# We are extracting data from different databanks and merging them in one for the identified indicators for all the 190 countries of World. We are doing the acquisition and preprocessing as well because this data is not available in single. Currently we have 65+ indicators which we will be clubbing to have some new dataframes and performing analysis on it. Once we find our main indicators we will be predicting the values of 2030 for them.
#
# Below we are using test data created just to show basic EDA of the dataset we have, its just limited to India in testdata but we are covering whole world in our project. The data extracted is from 1960 till 2017 but it needs to be cleaned. We will be performing detail analysis with clean dataset during our project.
#
# Showing some glimpse of data and its attributes below for India:

# %%
import pandas as pd

India_data = pd.read_csv(
    filepath_or_buffer= "TestData.csv", 
    sep = ",",
    header = 0
)

India_data.head(5)
# Out:
#   CountryName CountryCode                                         SeriesName  \
# 0       India         IND     Adjusted net national income (annual % growth)
# 1       India         IND         Adjusted net national income (current US$)
# 2       India         IND  Agricultural raw materials imports (% of merch...
# 3       India         IND  Agricultural raw materials exports (% of merch...
# 4       India         IND  Agriculture, forestry, and fishing, value adde...
#
#           SeriesCode 1960[YR1960] 1961[YR1961] 1962[YR1962] 1963[YR1963]  \
# 0  NY.ADJ.NNTY.KD.ZG           ..           ..           ..           ..
# 1     NY.ADJ.NNTY.CD           ..           ..           ..           ..
# 2  TM.VAL.AGRI.ZS.UN           ..           ..  9.242249308  8.603457071
# 3  TX.VAL.AGRI.ZS.UN           ..           ..  9.257298841  8.252923511
# 4     NV.AGR.TOTL.ZS  41.31283906  40.38740161   38.3713352  39.31975131
#
# ...

# %%
from collections import Counter

## initialize a counter for the positions
positions = Counter()

## loop over rows to count up the positions
for ix, row in India_data.iterrows():
    positions[row["Series Name"]] += 1

list(positions.keys())
# Out:
# ['Adjusted net national income (annual % growth)',
#  'Adjusted net national income (current US$)',
#  'Agricultural raw materials imports (% of merchandise imports)',
#  'Agricultural raw materials exports (% of merchandise exports)',
#  'Agriculture, forestry, and fishing, value added (% of GDP)',
#  'Arms exports (SIPRI trend indicator values)',
#  'Arms imports (SIPRI trend indicator values)',
#  'Bank capital to assets ratio (%)',
#  'Bank liquid reserves to bank assets ratio (%)',
#  'Broad money (% of GDP)',
#  'Central government debt, total (% of GDP)',
#  'Claims on central government, etc. (% GDP)',
#  'Claims on other sectors of the domestic economy (% of GDP)',
#  'Coal rents (% of GDP)',
#  'Commercial service exports (current US$)',
#  'Commercial service imports (current US$)',
#  'Current account balance (% of GDP)',
#  'Current health expenditure (% of GDP)',
#  'Domestic credit provided by financial sector (% of GDP)',
# ...

# %% [markdown]
# #### ● Discussion of who might be interested in your analysis
#
# As stated earlier this data contains the Revenue and financial data of countries combined which affect GDP and thus the growth of the country. It also tells the current position of the country amongst underdeveloped, developing or developed nations. This analysis would be useful for the finance department of any nation or the officers looking at the economic trend. This is much useful for economists who can further take this analysis to match the country's growth.

# %% [markdown]
# #### ● Discussion of how your analysis might fit into an application or investigation
#
# Under this project, we are focussing on the prediction of GDP and economic growth of the country depending on the variation of parameters. This project will also cover the different factors which can boom or burst the economy thus helpful for economists to bring superior plans to promote the nation's growth.

# %% [markdown]
# #### ● Discussion of how your analysis is limited and could be improved
#
# Currently, we are having the limited data which are made public from IMF and WorldBank so the analysis is done based on those data only. Also, the data is not rich for all parameters or indicators thus more rich data will give a better prediction. Also, this analysis is done on a very small scale as the knowledge of financial domain is limited to our members so we are not able to cover much but a max of them are in. We are learning a few economic journals to enrich our financial domain understanding and maybe we do some alterations later on while developing projects. Alteration in sense to make project rich not to change project :).

# %% [markdown]
# #### ● Selection of data for continued analysis, including justification
#
# Data is mainly captured from IMF and WorldBank databank after reading several journals and links related to finances. Some of them are presented below:
#
# IMF : http://data.imf.org/?sk=77413F1D-1525-450A-A23A-47AEED40FE78
#
# IMF : http://data.imf.org/?sk=07109577-E65D-4CE1-BB21-0CB3098FC504
#
# IMF : http://www.imf.org/en/Publications/WP/Issues/2017/03/29/World-Trade-in-Services-Evidence-from-A-New-Dataset-44776
#
# IMF : http://data.imf.org/bop
#
# WorldBank : http://datatopics.worldbank.org/world-development-indicators/
#
# IMF : https://www.imf.org/external/pubs/ft/fandd/basics/gdp.htm
#
# GDP can be viewed in three different ways:
#
# ● The production approach sums the “value-added” at each stage of production, where value-added is defined as total sales less the value of intermediate inputs into the production process. For example, flour would be an intermediate input and bread the final product; or an architect’s services would be an intermediate input and the building the final product.
#
# ● The expenditure approach adds up the value of purchases made by final users—for example, the consumption of food, televisions, and medical services by households; the investments in machinery by companies; and the purchases of goods and services by the government and foreigners.
#
# ● The income approach sums the incomes generated by production—for example, the compensation employees receive and the operating surplus of companies (roughly sales less costs).
#
# So we selected the parameters which are related to the approach above.

# %% [markdown]
# #### ● Discussion of how your analysis might be completed and disseminated, i.e., who's the target audience?
#
# Target audience as stated earlier may be any Data scientist, economist or finance officers looking for economic data for identifying the fallback and favor indicators for Nation's growth. Any industrialist can also look for the trade trend to extract maximum benefit through a wiki page of the trend analysis generated for the companies.
